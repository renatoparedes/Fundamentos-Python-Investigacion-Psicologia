# %% [markdown]
# # Visualización de datos con Seaborn
#
# >Este tutorial es una adaptación al español del tutorial [Plot With Pandas: Python Data Visualization for Beginners](https://realpython.com/pandas-plot-python/) desarrollado por Reka Hovath en el portal Real Python.

# %% [markdown]
# Ya sea que estés conociendo un conjunto de datos o te estés preparando para publicar tus hallazgos, la visualización es una herramienta esencial.
#
# La popular biblioteca de análisis de datos de Python Pandas ofrece varias opciones diferentes para visualizar sus datos con `.plot()`.
#
# Incluso si estás al comienzo de tu viaje de Pandas, pronto estarás creando gráficos básicos que producirán información valiosa sobre tus datos.

# %% [markdown]
# ## Preparativos
# Primero, descarga los datos pasando la URL de descarga a `pandas.read_csv()`:

# %%
import pandas as pd

download_url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv"
df = pd.read_csv(download_url)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Al llamar a `read_csv()`, creas un **DataFrame**, que es la estructura de datos principal utilizada en pandas.

# %% [markdown]
# Ahora que tienes un DataFrame, puedes echar un vistazo a los datos. Primero, debes configurar la opción display.max.columns para asegurarte de que pandas no oculte ninguna columna. Luego puede ver las primeras filas de datos con .head():

# %%
pd.set_option("display.max.columns", None)
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# 0       1849        270                  1207          37           0.018381
# 1        556        170                   388          85           0.117241
# 2        558        133                   340          16           0.024096
# 3       1069        150                   692          40           0.050125
# 4      23170       5180                 16697        1672           0.061098
#
#    Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0  110000  95000  125000          1534               364            193
# 1   75000  55000   90000           350               257             50
# 2   73000  50000  105000           456               176              0
# 3   70000  43000   80000           529               102              0
# 4   65000  50000   75000         18314              4440            972

# %% [markdown]
# El número predeterminado de filas que muestra `.head()` es cinco, pero puedes especificar cualquier número de filas como argumento. Por ejemplo, para mostrar las primeras diez filas, puedes usar `df.head(10)`.

# %% [markdown]
# ## Crea tu primera visualización con Pandas
# El conjunto de datos contiene algunas columnas relacionadas con los ingresos de los graduados en cada especialización:
#
# - La "mediana" es la mediana de los ingresos de los trabajadores a tiempo completo durante todo el año.
# - "P25th" es el percentil 25 de ganancias.
# - "P75th" es el percentil 75 de ganancias.
# - "Rank" es el ranking de la especialidad según la mediana de ingresos.

# %% [markdown]
# Comencemos con un gráfico que muestre estas columnas. Puedes hacerlo con `.plot()`:

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"]);

# %% [markdown]
# `.plot()` devuelve un gráfico de líneas que contiene los datos de cada fila en el DataFrame. Los valores del eje x representan el ranking de cada institución, y los valores "P25th", "Median" y "P75th" están graficados en el eje y. Al observar la gráfica puede hacer las siguientes observaciones:
#
# - El ingreso medio disminuye a medida que disminuye el ranking. Esto se espera porque el ranking está determinado por el ingreso medio.
# - Algunas carreras tienen grandes brechas entre los percentiles 25 y 75. Las personas con estos títulos pueden ganar significativamente menos o significativamente más que el ingreso medio.
# - Otras carreras tienen brechas muy pequeñas entre los percentiles 25 y 75. Las personas con estos títulos ganan salarios muy cercanos al ingreso medio.

# %% [markdown]
# ¡Tu primera visualización ya insinúa que hay mucho más por descubrir en los datos! Algunas carreras tienen una amplia gama de ingresos y otras tienen un rango bastante estrecho. Para descubrir estas diferencias, utilizarás varios otros tipos de gráficos.
#
# `.plot()` tiene varios parámetros opcionales. En particular, el parámetro `kind` acepta once valores de cadena diferentes y determina qué tipo de gráfico creará:
#
# - "area" es para parcelas de área.
# - "bar" es para gráficos de barras verticales.
# - "barh" es para gráficos de barras horizontales.
# - "box" es para diagramas de caja.
# - "hexbin" es para parcelas de hexbin.
# - "hist" es para histogramas.
# - "kde" es para gráficos de estimación de densidad de kernel.
# - "density" es un alias de "kde".
# - "line" es para gráficos de líneas.
# - "pie" es para gráficos circulares.
# - "scatter" es para diagramas de dispersión.

# %% [markdown]
# Intenta ahora agregar el argumento `kind` para el mismo gráfico, empleando los parámetros `box`, `hist` y `density`:

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"], kind="line");

# %% [markdown]
# Si no proporcionas los parámetros `x` e `y` a `.plot()`, entonces crea una gráfica de línea con el índice en el eje X y todas las columnas numéricas en el eje Y.
#
# Si bien este es un valor predeterminado útil para conjuntos de datos con solo unas pocas columnas, para el conjunto de datos de las especialidades universitarias y sus varias columnas numéricas, parece un desastre.

# %% [markdown]
# Inténtalo bajo tu propio riesgo:

# %%
df.plot(kind="line");

# %% [markdown]
# ## Mira bajo el capó: Matplotlib
# Cuando llamas a `.plot()` en un objeto DataFrame, Matplotlib crea la trama bajo el capó.
#
# Para verificar esto, prueba dos fragmentos de código.

# %% [markdown]
# Primero, crea una gráfica con Matplotlib usando dos columnas de su DataFrame:

# %%
import matplotlib.pyplot as plt

plt.plot(df["Rank"], df["P75th"]);

# %% [markdown]
# Primero, importas el módulo `matplotlib.pyplot` y le cambias el nombre a `plt`.
#
# Luego, llamas a `plot()` y pasas la columna "Rank" del objeto DataFrame como primer argumento y la columna "P75th" como segundo argumento.

# %% [markdown]
# Puede crear exactamente el mismo gráfico utilizando el método `.plot()` del objeto DataFrame:

# %%
df.plot(x="Rank", y="P75th");

# %% [markdown]
# `.plot()` es un contenedor (**wrapper**) para `pyplot.plot()`, y el resultado es un gráfico idéntico al que se produjo con Matplotlib.
#
# Puedes usar `pyplot.plot()` y `df.plot()` para producir el mismo gráfico a partir de columnas de un objeto DataFrame.
#
# Sin embargo, si ya tienes una instancia de DataFrame, `df.plot()` ofrece una sintaxis más limpia que `pyplot.plot()`.

# %% [markdown]
# ## Un wrapper destacado por su elegancia: Seaborn
#
# Pandas no es el único wrapper de Matplotlib. Matplotlib ofrece las bases para crear gráficos altamente personalizados. Por ello, existen muchos paquetes de visualización de datos en Python que se apoyan en esta librería.
#
# Dentro de ellas, una muy utilizada en la comunidad científica por su simplicidad y elegencia es `Seaborn`. Seaborn ofrece gráficos con configuraciones adaptadas al uso común que se da en la comunicación científica.

# %% [markdown]
# Para usar Seaborn, basta importarlo como las demás librerías:

# %%
import seaborn as sns

# %% [markdown]
# ## Explora tus datos con Seaborn
#
# Para demostrar el uso de Seaborn, vamos a explorar la base de datos "National Health and Nutrition Examination Survey" (NHANES) del gobierno estadounidense:

# %%
#!pip install nhanes
from nhanes.load import load_NHANES_data

nhanes_data = load_NHANES_data()
nhanes_data.head()
# Out:
#         GeneralHealthCondition  EverBreastfedOrFedBreastmilk  \
# SEQN
# 93703.0                    NaN                           1.0
# 93704.0                    NaN                           1.0
# 93705.0                   Good                           NaN
# 93706.0              Very good                           NaN
# 93707.0                   Good                           NaN
#
#          AgeStoppedBreastfeedingdays  AgeFirstFedFormuladays  \
# SEQN
# 93703.0                        273.0                     1.0
# 93704.0                         60.0                     3.0
# 93705.0                          NaN                     NaN
# 93706.0                          NaN                     NaN
# 93707.0                          NaN                     NaN
#
#          AgeStoppedReceivingFormuladays  AgeStartedOtherFoodbeverage  \
# SEQN
# 93703.0                           365.0                        152.0
# 93704.0                           365.0                        126.0
# 93705.0                             NaN                          NaN
# 93706.0                             NaN                          NaN
# 93707.0                             NaN                          NaN
#
#          AgeFirstFedMilkdays TypeOfMilkFirstFedWholeMilk  \
# SEQN
# 93703.0                365.0       Whole or regular milk
# 93704.0                365.0       Whole or regular milk
# 93705.0                  NaN                         NaN
# 93706.0                  NaN                         NaN
# 93707.0                  NaN                         NaN
#
#          TypeOfMilkFirstFed2Milk  TypeOfMilkFirstFed1Milk  \
# SEQN
# 93703.0                      NaN                      NaN
# 93704.0                      NaN                      NaN
# 93705.0                      NaN                      NaN
# 93706.0                      NaN                      NaN
# 93707.0                      NaN                      NaN
#
#          TypeOfMilkFirstFedFatFreeMilk  TypeOfMilkFirstFedSoyMilk  \
# SEQN
# 93703.0                            NaN                        NaN
# 93704.0                            NaN                        NaN
# 93705.0                            NaN                        NaN
# 93706.0                            NaN                        NaN
# 93707.0                            NaN                        NaN
#
#          TypeOfMilkFirstFedOther HowHealthyIsTheDiet  \
# SEQN
# 93703.0                      NaN                 NaN
# 93704.0                      NaN                 NaN
# 93705.0                      NaN                Good
# 93706.0                      NaN           Very good
# 93707.0                      NaN                 NaN
#
#                            Past30DayMilkProductConsumption  \
# SEQN
# 93703.0                          Often-once a day or more?
# 93704.0  Sometimes-once a week or more but less than on...
# 93705.0  Sometimes-once a week or more but less than on...
# 93706.0                                              Never
# 93707.0                                              Never
#
#         YouDrinkWholeOrRegularMilk  YouDrink2FatMilk  YouDrink1FatMilk  \
# SEQN
# 93703.0                        NaN               NaN              12.0
# 93704.0                        NaN               NaN              12.0
# 93705.0                        NaN               NaN               NaN
# 93706.0                        NaN               NaN               NaN
# 93707.0                        NaN               NaN               NaN
#
#          YouDrinkFatFreeskimMilk  YouDrinkSoyMilk  YouDrinkAnotherTypeOfMilk  \
# SEQN
# 93703.0                      NaN              NaN                        NaN
# 93704.0                      NaN              NaN                        NaN
# 93705.0                      NaN              NaN                       30.0
# 93706.0                      NaN              NaN                        NaN
# 93707.0                      NaN              NaN                        NaN
#
#                                RegularMilkUse5TimesPerWeek  \
# SEQN
# 93703.0                                                NaN
# 93704.0                                                NaN
# 93705.0  {My/His/Her} milk drinking has varied over {my...
# 93706.0                                                NaN
# 93707.0                                                NaN
#
#           HowOftenDrankMilkAge512  \
# SEQN
# 93703.0                       NaN
# 93704.0                       NaN
# 93705.0  Often-once a day or more
# 93706.0                       NaN
# 93707.0                       NaN
#
#                                   HowOftenDrankMilkAge1317  \
# SEQN
# 93703.0                                                NaN
# 93704.0                                                NaN
# 93705.0  Sometimes-once a week or more but less than on...
# 93706.0                                                NaN
# 93707.0                                                NaN
#
#                                   HowOftenDrankMilkAge1835  \
# SEQN
# 93703.0                                                NaN
# 93704.0                                                NaN
# 93705.0  Sometimes-once a week or more but less than on...
# 93706.0                                                NaN
# 93707.0                                                NaN
#
#          CommunitygovernmentMealsDelivered  EatMealsAtCommunityseniorCenter  \
# SEQN
# 93703.0                                NaN                              NaN
# 93704.0                                NaN                              NaN
# 93705.0                                0.0                              0.0
# 93706.0                                NaN                              NaN
# 93707.0                                NaN                              NaN
#
#          AttendKindergartenThruHighSchool  SchoolServesSchoolLunches  \
# SEQN
# 93703.0                               NaN                        NaN
# 93704.0                               NaN                        NaN
# 93705.0                               NaN                        NaN
# 93706.0                               0.0                        NaN
# 93707.0                               1.0                        1.0
#
#          OfTimesweekGetSchoolLunch SchoolLunchFreeReducedOrFullPrice  \
# SEQN
# 93703.0                        NaN                               NaN
# 93704.0                        NaN                               NaN
# 93705.0                        NaN                               NaN
# 93706.0                        NaN                               NaN
# 93707.0                        5.0                     Reduced price
#
#          SchoolServeCompleteBreakfastEachDay  OfTimesweekGetSchoolBreakfast  \
# SEQN
# 93703.0                                  NaN                            NaN
# 93704.0                                  NaN                            NaN
# 93705.0                                  NaN                            NaN
# 93706.0                                  NaN                            NaN
# 93707.0                                  1.0                            5.0
#
#         SchoolBreakfastFreereducedfullPrice SummerProgramMealFreereducedPrice  \
# SEQN
# 93703.0                                 NaN                               NaN
# 93704.0                                 NaN                               NaN
# 93705.0                                 NaN                               NaN
# 93706.0                                 NaN                               NaN
# 93707.0                       Reduced price     Did not attend summer program
#
#          OfMealsNotHomePrepared  OfMealsFromFastFoodOrPizzaPlace  \
# SEQN
# 93703.0            1.000000e+01                     5.397605e-79
# 93704.0            5.397605e-79                              NaN
# 93705.0            5.000000e+00                     5.397605e-79
# 93706.0            6.000000e+00                     3.000000e+00
# 93707.0            1.000000e+00                     1.000000e+00
#
#          OfReadytoeatFoodsInPast30Days  OfFrozenMealspizzaInPast30Days  \
# SEQN
# 93703.0                   5.397605e-79                    1.000000e+00
# 93704.0                   5.397605e-79                    5.397605e-79
# 93705.0                   5.397605e-79                    5.397605e-79
# 93706.0                   5.397605e-79                    5.397605e-79
# 93707.0                   6.000000e+00                    4.000000e+00
#
#          HeardOfMyPlate  LookedUpMyPlateOnInternet  TriedMyPlatePlan  \
# SEQN
# 93703.0             NaN                        NaN               NaN
# 93704.0             NaN                        NaN               NaN
# 93705.0             0.0                        NaN               NaN
# 93706.0             0.0                        NaN               NaN
# 93707.0             NaN                        NaN               NaN
#
#          MainMealPlannerpreparer  SharedMealPlanningpreparingDuty  \
# SEQN
# 93703.0                      NaN                              NaN
# 93704.0                      NaN                              NaN
# 93705.0                      1.0                              0.0
# 93706.0                      0.0                              1.0
# 93707.0                      NaN                              NaN
#
#          MainFoodShopper  SharedFoodShoppingDuty  \
# SEQN
# 93703.0              NaN                     NaN
# 93704.0              NaN                     NaN
# 93705.0              1.0                     0.0
# 93706.0              0.0                     1.0
# 93707.0              NaN                     NaN
#
#          HaveSeriousDifficultyHearing  HaveSeriousDifficultySeeing  \
# SEQN
# 93703.0                           0.0                          0.0
# 93704.0                           0.0                          0.0
# 93705.0                           0.0                          0.0
# 93706.0                           0.0                          0.0
# 93707.0                           0.0                          0.0
#
#          HaveSeriousDifficultyConcentrating  HaveSeriousDifficultyWalking  \
# SEQN
# 93703.0                                 NaN                           NaN
# 93704.0                                 NaN                           NaN
# 93705.0                                 0.0                           0.0
# 93706.0                                 0.0                           0.0
# 93707.0                                 0.0                           0.0
#
#          HaveDifficultyDressingOrBathing  HaveDifficultyDoingErrandsAlone  \
# SEQN
# 93703.0                              NaN                              NaN
# 93704.0                              NaN                              NaN
# 93705.0                              0.0                              0.0
# 93706.0                              0.0                              0.0
# 93707.0                              0.0                              NaN
#
#          HowOftenDoYouFeelWorriedOrAnxious  TakeMedicationForTheseFeelings  \
# SEQN
# 93703.0                                NaN                             NaN
# 93704.0                                NaN                             NaN
# 93705.0                                1.0                             0.0
# 93706.0                                0.0                             0.0
# 93707.0                                NaN                             NaN
#
#          HowOftenDoYouFeelDepressed  TakeMedicationForDepression  \
# SEQN
# 93703.0                         NaN                          NaN
# 93704.0                         NaN                          NaN
# 93705.0                         1.0                          0.0
# 93706.0                         0.0                          0.0
# 93707.0                         NaN                          NaN
#
#          CoveredByHealthInsurance UsualSleepTimeOnWeekdaysOrWorkdays  \
# SEQN
# 93703.0                       1.0                                NaN
# 93704.0                       1.0                                NaN
# 93705.0                       1.0                           b'23:00'
# 93706.0                       1.0                           b'23:30'
# 93707.0                       1.0                                NaN
#
#         UsualWakeTimeOnWeekdaysOrWorkdays  SleepHoursWeekdaysOrWorkdays  \
# SEQN
# 93703.0                               NaN                           NaN
# 93704.0                               NaN                           NaN
# 93705.0                          b'07:00'                           8.0
# 93706.0                          b'10:00'                          10.5
# 93707.0                               NaN                           NaN
#
#                        HowOftenDoYouSnore  EverToldDoctorHadTroubleSleeping  \
# SEQN
# 93703.0                               NaN                               NaN
# 93704.0                               NaN                               NaN
# 93705.0  Occasionally - 3-4 nights a week                               0.0
# 93706.0        Rarely - 1-2 nights a week                               0.0
# 93707.0                               NaN                               NaN
#
#         HowOftenFeelOverlySleepyDuringDay  HaveLittleInterestInDoingThings  \
# SEQN
# 93703.0                               NaN                              NaN
# 93704.0                               NaN                              NaN
# 93705.0                             Never                              0.0
# 93706.0           Rarely - 1 time a month                              0.0
# 93707.0                               NaN                              NaN
#
#          FeelingDownDepressedOrHopeless  TroubleSleepingOrSleepingTooMuch  \
# SEQN
# 93703.0                             NaN                               NaN
# 93704.0                             NaN                               NaN
# 93705.0                             0.0                               0.0
# 93706.0                             0.0                               0.0
# 93707.0                             NaN                               NaN
#
#          FeelingTiredOrHavingLittleEnergy  PoorAppetiteOrOvereating  \
# SEQN
# 93703.0                               NaN                       NaN
# 93704.0                               NaN                       NaN
# 93705.0                               0.0                       0.0
# 93706.0                               0.0                       0.0
# 93707.0                               NaN                       NaN
#
#          FeelingBadAboutYourself  TroubleConcentratingOnThings  \
# SEQN
# 93703.0                      NaN                           NaN
# 93704.0                      NaN                           NaN
# 93705.0                      0.0                           0.0
# 93706.0                      0.0                           0.0
# 93707.0                      NaN                           NaN
#
#          MovingOrSpeakingSlowlyOrTooFast  ThoughtYouWouldBeBetterOffDead  \
# SEQN
# 93703.0                              NaN                             NaN
# 93704.0                              NaN                             NaN
# 93705.0                              0.0                             0.0
# 93706.0                              0.0                             0.0
# 93707.0                              NaN                             NaN
#
#         DifficultyTheseProblemsHaveCaused  SmokedTobaccoLast5Days  \
# SEQN
# 93703.0                               NaN                     NaN
# 93704.0                               NaN                     NaN
# 93705.0                               NaN                     0.0
# 93706.0                               NaN                     0.0
# 93707.0                               NaN                     0.0
#
#          DaysSmokedCigarettesLast5Days  CigarettesSmokedPerDay  \
# SEQN
# 93703.0                            NaN                     NaN
# 93704.0                            NaN                     NaN
# 93705.0                            NaN                     NaN
# 93706.0                            NaN                     NaN
# 93707.0                            NaN                     NaN
#
#          UsedAnyTobaccoProductLast5Days  ExperienceConfusionmemoryProblems  \
# SEQN
# 93703.0                             NaN                                NaN
# 93704.0                             NaN                                NaN
# 93705.0                             0.0                                0.0
# 93706.0                             0.0                                NaN
# 93707.0                             0.0                                NaN
#
#          PhysicalMentalEmotionalLimitations DifficultyManagingMoney  \
# SEQN
# 93703.0                                 NaN                     NaN
# 93704.0                                 NaN                     NaN
# 93705.0                                 0.0           No difficulty
# 93706.0                                 NaN                     NaN
# 93707.0                                 NaN                     NaN
#
#          60SecHr30SecHr2  60SecPulse30SecPulse2  SystolicBloodPres1StRdgMmHg  \
# SEQN
# 93703.0            120.0                    NaN                          NaN
# 93704.0            114.0                    NaN                          NaN
# 93705.0              NaN                   52.0                          NaN
# 93706.0              NaN                   82.0                        112.0
# 93707.0              NaN                  100.0                        128.0
#
#          DiastolicBloodPres1StRdgMmHg  SystolicBloodPres2NdRdgMmHg  \
# SEQN
# 93703.0                           NaN                          NaN
# 93704.0                           NaN                          NaN
# 93705.0                           NaN                          NaN
# 93706.0                          74.0                        114.0
# 93707.0                          38.0                        128.0
#
#          DiastolicBloodPres2NdRdgMmHg  SystolicBloodPres3RdRdgMmHg  \
# SEQN
# 93703.0                           NaN                          NaN
# 93704.0                           NaN                          NaN
# 93705.0                           NaN                        202.0
# 93706.0                          70.0                        108.0
# 93707.0                          46.0                        128.0
#
#          DiastolicBloodPres3RdRdgMmHg  EnergyKcal_DR2TOT  ProteinGm_DR2TOT  \
# SEQN
# 93703.0                           NaN                NaN               NaN
# 93704.0                           NaN             1356.0             30.49
# 93705.0                          62.0             1235.0             38.52
# 93706.0                          76.0                NaN               NaN
# 93707.0                          58.0             1794.0             92.03
#
#          CarbohydrateGm_DR2TOT  TotalSugarsGm_DR2TOT  DietaryFiberGm_DR2TOT  \
# SEQN
# 93703.0                    NaN                   NaN                    NaN
# 93704.0                 229.69                134.37                    8.2
# 93705.0                 147.49                 43.04                   13.1
# 93706.0                    NaN                   NaN                    NaN
# 93707.0                 153.12                 85.81                    7.9
#
#          TotalFatGm_DR2TOT  TotalSaturatedFattyAcidsGm_DR2TOT  \
# SEQN
# 93703.0                NaN                                NaN
# 93704.0              37.02                             10.368
# 93705.0              55.19                             14.079
# 93706.0                NaN                                NaN
# 93707.0              93.98                             31.098
#
#          TotalMonounsaturatedFattyAcidsGm_DR2TOT  \
# SEQN
# 93703.0                                      NaN
# 93704.0                                   10.443
# 93705.0                                   19.882
# 93706.0                                      NaN
# 93707.0                                   35.405
#
#          TotalPolyunsaturatedFattyAcidsGm_DR2TOT  CholesterolMg_DR2TOT  \
# SEQN
# 93703.0                                      NaN                   NaN
# 93704.0                                   13.249                  70.0
# 93705.0                                   17.072                 402.0
# 93706.0                                      NaN                   NaN
# 93707.0                                   17.827                 656.0
#
#          AlcoholGm_DR2TOT  WeightKg  RecumbentLengthCm  StandingHeightCm  \
# SEQN
# 93703.0               NaN      13.7               89.6              88.6
# 93704.0      5.397605e-79      13.9               95.0              94.2
# 93705.0      5.397605e-79      79.5                NaN             158.3
# 93706.0               NaN      66.3                NaN             175.7
# 93707.0      5.397605e-79      45.4                NaN             158.4
#
#          BodyMassIndexKgm2  WaistCircumferenceCm  DirectHdlcholesterolMgdl  \
# SEQN
# 93703.0               17.5                  48.2                       NaN
# 93704.0               15.7                  50.0                       NaN
# 93705.0               31.7                 101.8                      60.0
# 93706.0               21.5                  79.3                      47.0
# 93707.0               18.1                  64.1                      68.0
#
#          TotalCholesterolMgdl  VigorousWorkActivity  ModerateWorkActivity  \
# SEQN
# 93703.0                   NaN                   NaN                   NaN
# 93704.0                   NaN                   NaN                   NaN
# 93705.0                 157.0                   0.0                   0.0
# 93706.0                 148.0                   0.0                   0.0
# 93707.0                 189.0                   NaN                   NaN
#
#          WalkOrBicycle  VigorousRecreationalActivities  \
# SEQN
# 93703.0            NaN                             NaN
# 93704.0            NaN                             NaN
# 93705.0            0.0                             0.0
# 93706.0            1.0                             0.0
# 93707.0            NaN                             NaN
#
#          ModerateRecreationalActivities  MinutesSedentaryActivity  \
# SEQN
# 93703.0                             NaN                       NaN
# 93704.0                             NaN                       NaN
# 93705.0                             1.0                     300.0
# 93706.0                             1.0                     240.0
# 93707.0                             NaN                       NaN
#
#          EverBeenToldYouHaveAsthma  DoctorEverSaidYouHadArthritis  \
# SEQN
# 93703.0                        0.0                            NaN
# 93704.0                        0.0                            NaN
# 93705.0                        1.0                            1.0
# 93706.0                        0.0                            NaN
# 93707.0                        0.0                            NaN
#
#          EverToldYouHadHeartAttack  AgeWhenToldYouHadHeartAttack  \
# SEQN
# 93703.0                        NaN                           NaN
# 93704.0                        NaN                           NaN
# 93705.0                        0.0                           NaN
# 93706.0                        NaN                           NaN
# 93707.0                        NaN                           NaN
#
#          EverToldYouHadAStroke  AgeWhenToldYouHadAStroke  \
# SEQN
# 93703.0                    NaN                       NaN
# 93704.0                    NaN                       NaN
# 93705.0                    0.0                       NaN
# 93706.0                    NaN                       NaN
# 93707.0                    NaN                       NaN
#
#          EverToldYouHadCancerOrMalignancy  1StCancerWhatKindWasIt  \
# SEQN
# 93703.0                               NaN                     NaN
# 93704.0                               NaN                     NaN
# 93705.0                               0.0                     NaN
# 93706.0                               NaN                     NaN
# 93707.0                               NaN                     NaN
#
#          Age1StCancerMcq230ADiagnosed  EverUsedMarijuanaOrHashish  \
# SEQN
# 93703.0                           NaN                         NaN
# 93704.0                           NaN                         NaN
# 93705.0                           NaN                         NaN
# 93706.0                           NaN                         0.0
# 93707.0                           NaN                         NaN
#
#          DaysUsedMarijuanaOrHashishmonth  \
# SEQN
# 93703.0                              NaN
# 93704.0                              NaN
# 93705.0                              NaN
# 93706.0                              NaN
# 93707.0                              NaN
#
#          EverUsedCocaineheroinmethamphetamine  EverUseAnyFormOfCocaine  \
# SEQN
# 93703.0                                   NaN                      NaN
# 93704.0                                   NaN                      NaN
# 93705.0                                   0.0                      NaN
# 93706.0                                   0.0                      NaN
# 93707.0                                   NaN                      NaN
#
#          OfDaysUsedCocainemonth  EverUsedHeroin  OfDaysUsedHeroinmonth  \
# SEQN
# 93703.0                     NaN             NaN                    NaN
# 93704.0                     NaN             NaN                    NaN
# 93705.0                     NaN             NaN                    NaN
# 93706.0                     NaN             NaN                    NaN
# 93707.0                     NaN             NaN                    NaN
#
#          EverUsedMethamphetamine  DaysUsedMethamphetaminemonth  \
# SEQN
# 93703.0                      NaN                           NaN
# 93704.0                      NaN                           NaN
# 93705.0                      NaN                           NaN
# 93706.0                      NaN                           NaN
# 93707.0                      NaN                           NaN
#
#          EverBeenInRehabilitationProgram  BloodLeadUgdl  BloodCadmiumUgl  \
# SEQN
# 93703.0                              NaN            NaN              NaN
# 93704.0                              NaN            NaN             0.07
# 93705.0                              NaN           2.98             0.24
# 93706.0                              NaN           0.74             0.21
# 93707.0                              NaN           0.39             0.14
#
#          BloodMercuryTotalUgl  BloodSeleniumUgl  BloodManganeseUgl  Gender  \
# SEQN
# 93703.0                   NaN               NaN                NaN  Female
# 93704.0                  0.47            142.28               9.41    Male
# 93705.0                  1.07            185.71               8.57  Female
# 93706.0                 10.64            199.44              14.07    Male
# 93707.0                  0.20            179.34              12.60    Male
#
#          AgeInYearsAtScreening  AgeInMonthsAtScreening0To24Mos  \
# SEQN
# 93703.0                    2.0                             NaN
# 93704.0                    2.0                             NaN
# 93705.0                   66.0                             NaN
# 93706.0                   18.0                             NaN
# 93707.0                   13.0                             NaN
#
#                           RacehispanicOrigin  \
# SEQN
# 93703.0  Other Race - Including Multi-Racial
# 93704.0                   Non-Hispanic White
# 93705.0                   Non-Hispanic Black
# 93706.0  Other Race - Including Multi-Racial
# 93707.0  Other Race - Including Multi-Racial
#
#                   RacehispanicOriginWNhAsian ServedActiveDutyInUsArmedForces  \
# SEQN
# 93703.0                   Non-Hispanic Asian                             NaN
# 93704.0                   Non-Hispanic White                             NaN
# 93705.0                   Non-Hispanic Black                               0
# 93706.0                   Non-Hispanic Asian                               0
# 93707.0  Other Race - Including Multi-Racial                             NaN
#
#         EducationLevelChildrenyouth619  \
# SEQN
# 93703.0                            NaN
# 93704.0                            NaN
# 93705.0                            NaN
# 93706.0          More than high school
# 93707.0                      6th grade
#
#                                     EducationLevelAdults20 MaritalStatus  \
# SEQN
# 93703.0                                                NaN           NaN
# 93704.0                                                NaN           NaN
# 93705.0  9-11th grade (Includes 12th grade with no dipl...      Divorced
# 93706.0                                                NaN           NaN
# 93707.0                                                NaN           NaN
#
#          TotalNumberOfPeopleInTheHousehold  TotalNumberOfPeopleInTheFamily  \
# SEQN
# 93703.0                                  5                               5
# 93704.0                                  4                               4
# 93705.0                                  1                               1
# 93706.0                                  5                               5
# 93707.0  7 or more people in the Household  7 or more people in the Family
#
#         OfChildren5YearsOrYoungerInHh OfChildren617YearsOldInHh  \
# SEQN
# 93703.0                     3 or more                         0
# 93704.0                             2                         0
# 93705.0                             0                         0
# 93706.0                             0                         0
# 93707.0                             0                 3 or more
#
#         OfAdults60YearsOrOlderInHh  AnnualHouseholdIncome  AnnualFamilyIncome  \
# SEQN
# 93703.0                          0               100000.0            100000.0
# 93704.0                          0               100000.0            100000.0
# 93705.0                          1                12500.0             12500.0
# 93706.0                          1                    NaN                 NaN
# 93707.0                          0                70000.0             70000.0
#
#          RatioOfFamilyIncomeToPoverty  TrunkFatG  TrunkPercentFat  \
# SEQN
# 93703.0                          5.00        NaN              NaN
# 93704.0                          5.00        NaN              NaN
# 93705.0                          0.82        NaN              NaN
# 93706.0                           NaN     6358.9             20.9
# 93707.0                          1.88     2972.8             15.7
#
#          TotalPercentFat HowOftenAddSaltToFoodAtTable  OnSpecialDiet  \
# SEQN
# 93703.0              NaN                          NaN            NaN
# 93704.0              NaN                          NaN            0.0
# 93705.0              NaN                          NaN            0.0
# 93706.0             22.7                       Rarely            0.0
# 93707.0             19.0                          NaN            0.0
#
#          WeightLosslowCalorieDiet  LowFatlowCholesterolDiet  \
# SEQN
# 93703.0                       NaN                       NaN
# 93704.0                       NaN                       NaN
# 93705.0                       NaN                       NaN
# 93706.0                       NaN                       NaN
# 93707.0                       NaN                       NaN
#
#          LowSaltlowSodiumDiet  DiabeticDiet  LowCarbohydrateDiet  \
# SEQN
# 93703.0                   NaN           NaN                  NaN
# 93704.0                   NaN           NaN                  NaN
# 93705.0                   NaN           NaN                  NaN
# 93706.0                   NaN           NaN                  NaN
# 93707.0                   NaN           NaN                  NaN
#
#          EnergyKcal_DR1TOT  ProteinGm_DR1TOT  CarbohydrateGm_DR1TOT  \
# SEQN
# 93703.0                NaN               NaN                    NaN
# 93704.0             1230.0             51.58                 160.46
# 93705.0             1202.0             20.01                 157.45
# 93706.0             1987.0             94.19                  89.82
# 93707.0             1775.0             59.48                 188.15
#
#          TotalSugarsGm_DR1TOT  DietaryFiberGm_DR1TOT  TotalFatGm_DR1TOT  \
# SEQN
# 93703.0                   NaN                    NaN                NaN
# 93704.0                 76.97                    5.9              43.24
# 93705.0                 91.55                    8.4              56.98
# 93706.0                 14.73                    7.1             137.39
# 93707.0                 84.22                   10.9              89.18
#
#          TotalSaturatedFattyAcidsGm_DR1TOT  \
# SEQN
# 93703.0                                NaN
# 93704.0                             11.372
# 93705.0                             16.435
# 93706.0                             35.169
# 93707.0                             33.252
#
#          TotalMonounsaturatedFattyAcidsGm_DR1TOT  \
# SEQN
# 93703.0                                      NaN
# 93704.0                                   14.333
# 93705.0                                   16.432
# 93706.0                                   45.805
# 93707.0                                   33.712
#
#          TotalPolyunsaturatedFattyAcidsGm_DR1TOT  CholesterolMg_DR1TOT  \
# SEQN
# 93703.0                                      NaN                   NaN
# 93704.0                                   12.506                 144.0
# 93705.0                                   19.786                  14.0
# 93706.0                                   49.873                 462.0
# 93707.0                                   12.424                 585.0
#
#          AlcoholGm_DR1TOT  TunaEatenDuringPast30Days  \
# SEQN
# 93703.0               NaN                        NaN
# 93704.0      5.397605e-79                        0.0
# 93705.0      5.397605e-79                        NaN
# 93706.0      5.397605e-79                        0.0
# 93707.0      5.397605e-79                        NaN
#
#         DoctorToldYouHaveDiabetes  AgeWhenFirstToldYouHadDiabetes  \
# SEQN
# 93703.0                         0                             NaN
# 93704.0                         0                             NaN
# 93705.0                         0                             NaN
# 93706.0                         0                             NaN
# 93707.0                         0                             NaN
#
#          EverToldYouHavePrediabetes  EverToldHaveHealthRiskForDiabetes  \
# SEQN
# 93703.0                         NaN                                NaN
# 93704.0                         NaN                                NaN
# 93705.0                         0.0                                0.0
# 93706.0                         0.0                                0.0
# 93707.0                         0.0                                0.0
#
#         FamilyHistory  TakingInsulinNow  TakeDiabeticPillsToLowerBloodSugar  \
# SEQN
# 93703.0           NaN               0.0                                 NaN
# 93704.0           NaN               0.0                                 NaN
# 93705.0           NaN               0.0                                 NaN
# 93706.0           NaN               0.0                                 NaN
# 93707.0           NaN               0.0                                 NaN
#
#          WhatWasYourLastA1CLevel  Glycohemoglobin  \
# SEQN
# 93703.0                      NaN              NaN
# 93704.0                      NaN              NaN
# 93705.0                      NaN              6.2
# 93706.0                      NaN              5.2
# 93707.0                      NaN              5.6
#
#          SmokedAtLeast100CigarettesInLife  \
# SEQN
# 93703.0                               NaN
# 93704.0                               NaN
# 93705.0                               1.0
# 93706.0                               0.0
# 93707.0                               NaN
#
#          AgeStartedSmokingCigarettesRegularly DoYouNowSmokeCigarettes  \
# SEQN
# 93703.0                                   NaN                     NaN
# 93704.0                                   NaN                     NaN
# 93705.0                                  16.0              Not at all
# 93706.0                                   NaN                     NaN
# 93707.0                                   NaN                     NaN
#
#          DaysSmokedCigsDuringPast30Days  AvgCigarettesdayDuringPast30Days  \
# SEQN
# 93703.0                             NaN                               NaN
# 93704.0                             NaN                               NaN
# 93705.0                             NaN                               NaN
# 93706.0                             NaN                               NaN
# 93707.0                             NaN                               NaN
#
#          TriedToQuitSmoking  TimesStoppedSmokingCigarettes  \
# SEQN
# 93703.0                 NaN                            NaN
# 93704.0                 NaN                            NaN
# 93705.0                 NaN                            NaN
# 93706.0                 NaN                            NaN
# 93707.0                 NaN                            NaN
#
#          HowLongWereYouAbleToStopSmoking UnitOfMeasureDayweekmonthyear_2_SMQ  \
# SEQN
# 93703.0                              NaN                                 NaN
# 93704.0                              NaN                                 NaN
# 93705.0                              NaN                                 NaN
# 93706.0                              NaN                                 NaN
# 93707.0                              NaN                                 NaN
#
#          CurrentSelfreportedHeightInches  CurrentSelfreportedWeightPounds  \
# SEQN
# 93703.0                              NaN                              NaN
# 93704.0                              NaN                              NaN
# 93705.0                             63.0                            165.0
# 93706.0                             68.0                            145.0
# 93707.0                              NaN                              NaN
#
#          TriedToLoseWeightInPastYear TimesLost10LbsOrMoreToLoseWeight
# SEQN
# 93703.0                          NaN                              NaN
# 93704.0                          NaN                              NaN
# 93705.0                          0.0                 11 times or more
# 93706.0                          0.0                            Never
# 93707.0                          NaN                              NaN

# %% [markdown]
# ### Histogramas
#
# Podemos crear un histograma con el método `histplot` disponible en Seaborn:

# %%
import matplotlib.pyplot as plt

histogram = sns.histplot(x="AgeInYearsAtScreening", data=nhanes_data)
histogram.set_xlabel("Edades", fontsize=14)
histogram.set_ylabel("Conteo", fontsize=14)
plt.show()

# %% [markdown]
# En general, la sintaxis de Seaborn pide especificar un parámetro para el argumento `data` y precisar los ejes en los argumentos `x` e `y`.
#
# Podemos personalizar el gráfico recurriendo a métodos de Matplotlib como `set_xlabel` y `set_ylabel` para configurar los títulos de los ejes. Al finalizar usamos la sentencia `plt.show()` para que muestre el gráfico en nuestra interfaz.

# %% [markdown]
# Los histogramas pueden recibir un argumento extra llamado `bins` que permite delimitar el ancho de las barras.
#
# Veamos un ejemplo:

# %%
import numpy as np

custom_bins = np.arange(
    nhanes_data["AgeInYearsAtScreening"].min(),
    nhanes_data["AgeInYearsAtScreening"].max() + 1,
    step=1,
)

bin_histogram = sns.histplot(
    x="AgeInYearsAtScreening", data=nhanes_data, bins=custom_bins
)
bin_histogram.set_xlabel("Edades", fontsize=14)
bin_histogram.set_ylabel("Conteo", fontsize=14)
plt.show()

# %% [markdown]
# Aquí creamos bins personalizados empleando un método de numpy llamado `arange`, el cual es util para generar rangos de datos.

# %% [markdown]
# Podemos pedir a Seaborn que dibuje una linea para representar los histogramas mediante el proceso Kernel Density Estimation, usando el argumento `kde`:

# %%
kde_bin_histogram = sns.histplot(
    x="AgeInYearsAtScreening", data=nhanes_data, bins=custom_bins, kde=True
)
kde_bin_histogram.set_xlabel("Edades", fontsize=14)
kde_bin_histogram.set_ylabel("Conteo", fontsize=14)
plt.show()

# %% [markdown]
# ### Gráficos de dos variables
#
# Otro uso común de la visualización es examinar la relación entre dos variables. Por ejemplo, digamos que queríamos graficar la altura promedio en función de la edad en el conjunto de datos de NHANES.

# %% [markdown]
# Generemos este gráfico con Seaborn:

# %%
age_and_height = sns.lineplot(
    x="AgeInYearsAtScreening",
    y="StandingHeightCm",
    data=nhanes_data,
)
age_and_height.set_xlabel("Edad", size=14)
age_and_height.set_ylabel("Altura (cm)", size=14)
plt.show()

# %% [markdown]
# Seaborn por defecto nos arroja el promedio y el intervalo de confianza de los datos agrupados por edad. Vemos el intervalo de confianza sombreado alrededor de la línea.

# %% [markdown]
# Podemos pedirle a Seaborn que en el mismo gráfico nos genere una línea para hombres y otra para mujeres:

# %%
age_and_height = sns.lineplot(
    x="AgeInYearsAtScreening",
    y="StandingHeightCm",
    hue="Gender",
    data=nhanes_data,
)
age_and_height.set_xlabel("Edad", size=14)
age_and_height.set_ylabel("Altura (cm)", size=14)
age_and_height.legend(
    ["Femenino", "IC Femenino", "Masculino", "IC Masculino"], title="Género"
)
plt.show()

# %% [markdown]
# Esto fue gracias al argumento `hue`, el cual nos permite agrupar los resultados en función a una tercera variable, en este caso `Gender`.

# %% [markdown]
# #### Gráficos de cajas
#
# Un trabajo importante de la visualización estadística es mostrarnos la variabilidad o dispersión de nuestros datos. Ya hemos visto cómo hacer esto usando histogramas; ahora veamos cómo podemos comparar distribuciones.

# %% [markdown]
# Comencemos con un ejemplo simple: comparar la altura de hombres y mujeres adultos en la muestra de NHANES. Un diagrama de uso común es el diagrama de caja (a veces conocido como diagrama de caja y bigotes).
#
# Generemos un gráfico de cajas con Seaborn:

# %%
adult_nhanes_data = nhanes_data.query("AgeInYearsAtScreening > 17")
boxplot = sns.boxplot(x="Gender", y="StandingHeightCm", data=adult_nhanes_data)
boxplot.set_xlabel("Género", size=14)
boxplot.set_ylabel("Altura (cm)", size=14)
plt.xticks([0, 1], ["Femenino", "Masculino"])
plt.show()

# %% [markdown]
# Pudimos generar este gráfico llamando a la función `boxplot` y precisando los argumentos básicos: `data`, `x` e `y`.
#
# Para trabajar solo con los adultos, aplicamos un filtro a nuestra base de datos con el método `query` de pandas.

# %% [markdown]
# Otro tipo de gráfico que se usa comúnmente es el gráfico de violín, que muestra la forma de toda la distribución:

# %%
violinplot = sns.violinplot(
    x="Gender", y="StandingHeightCm", data=adult_nhanes_data
)
violinplot.set_xlabel("Género", size=14)
violinplot.set_ylabel("Altura (cm)", size=14)
plt.xticks([0, 1], ["Femenino", "Masculino"])
plt.show()

# %% [markdown]
# ## Buscar correlaciones
# A menudo, deseas ver si dos columnas de un conjunto de datos están conectadas.
#
# Por ejemplo, podemos explorar si el peso y la altura de los adultos está relacionada:

# %%
corr_plot = sns.scatterplot(
    x="StandingHeightCm", y="WeightKg", data=adult_nhanes_data
)

corr_plot.set_xlabel("Altura (cm)", size=14)
corr_plot.set_ylabel("Peso (kg)", size=14)
plt.show()

# %% [markdown]
# Con Seaborn, podemos pedir más de un gráfico de correlación a la vez:
#
# (Para demostrar este punto usaremos una base de datos más pequeña para reducir el tiempo de cómputo).

# %%
# Cargamos los datos
df_subsdis = pd.read_csv(
    "https://raw.githubusercontent.com/renatoparedes/IntroPythonInvestigacionPsicologia/master/AnalisisdeDatosCuantitativos/depression-data-subsdis.csv"
)
df_subsdis.drop(columns=["year"], inplace=True)

# Generamos el gráfico
sns.pairplot(df_subsdis, diag_kind="kde")
plt.show()

# %% [markdown]
# ## Configuraciones globales

# %% [markdown]
# Seaborn ofrece la posibilidad de establecer configuraciones globales para todos los plots que generes dentro de un mismo documento (notebook/script). Esto contempla desde el tamaño de los títulos de los ejes o la paleta de colores a utilizar.
#
# A continuación una configuración común para artículos académicos:

# %%
# Seaborn config
sns.set_context("paper")
sns.set_theme(
    style="ticks",
    palette="gray",
    rc={"axes.labelsize": 14, "axes.labelweight": "bold"},
)

# %% [markdown]
# Para más detalles, te invito a revisar la [documentación de Seaborn](https://seaborn.pydata.org/tutorial.html).
